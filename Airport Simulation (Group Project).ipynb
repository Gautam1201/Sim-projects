# %%
import simpy
import random
import matplotlib.pyplot as plt

import sys
from PyQt5.QtCore import QSize
from PyQt5.QtWidgets import QMainWindow, QLabel, QPushButton, QApplication
from PyQt5.QtGui import QFont
import time

class Airport(object):
    totalCheckin = 0
    totalSecurity = 0
    totalBoarding = 0
    cur_passenger = 0
    avgCheckin = []
    avgBoarding = []
    avgSecurity = []
    def __init__(self, num_checkin = 5, num_security = 5, num_boarding = 1, num_passengers = 100, arrival_limit = 100):
        self.env = simpy.Environment()
        self.num_checkin = num_checkin
        self.num_security = num_security
        self.num_boarding = num_boarding
        self.curr_checkin = 0
        self.curr_security = 0
        self.curr_boarding = 0
        self.curr_done = 0
        self.checkin = simpy.Resource(self.env, num_checkin)
        self.security = simpy.Resource(self.env, num_security)
        self.boarding = simpy.Resource(self.env, num_boarding)
        self.num_passengers = num_passengers
        self.passengers = [
            Passenger(self, random.randint(0, arrival_limit)) for i in range(num_passengers)
        ]

class Passenger(object):
    def __init__(self, airport, arrival_time):
        self.arrival_t = arrival_time
        self.airport = airport
        self.action = self.airport.env.process(self.run())
    def run(self):

        #wait for arrival
        delta = self.arrival_t - self.airport.env.now
        yield self.airport.env.timeout(delta)
        print("time:", self.airport.env.now, "passenger arrived")

        #check in 
        with self.airport.checkin.request() as request:
            yield request
            #do the check in
            self.airport.curr_checkin += 1
            yield self.airport.env.timeout(random.randint(1,5)) # 1-5 minutes to check in
            self.airport.curr_checkin -= 1
        print("time:", self.airport.env.now, "checking in done")
        self.airport.totalCheckin += self.airport.env.now - self.arrival_t


        #security
        with self.airport.security.request() as request:
            yield request
            #do the security
            self.airport.curr_security+=1
            yield self.airport.env.timeout(random.randint(2,6)) # 2-6 minutes
            self.airport.curr_security -= 1
        print("time:", self.airport.env.now, "security check done")
        self.airport.totalSecurity += self.airport.env.now - self.arrival_t

        #boarding
        with self.airport.boarding.request() as request:
            yield request
            #do the boarding
            self.airport.curr_boarding += 1
            yield self.airport.env.timeout(random.randint(1,2)) #1-2 minutes to board
            self.airport.curr_boarding -= 1
        print("time:", self.airport.env.now, "boarding done")
        self.airport.curr_done += 1
        print("time:", self.airport.env.now, f"passenger arrived at {self.arrival_t} and done at {self.airport.env.now}")
        self.airport.totalBoarding += self.airport.env.now - self.arrival_t
        self.airport.cur_passenger = self.airport.cur_passenger + 1
        # Statistics
        
        self.airport.avgCheckin.append(self.airport.totalCheckin/self.airport.cur_passenger)
        self.airport.avgSecurity.append(self.airport.totalSecurity/self.airport.cur_passenger)
        self.airport.avgBoarding.append(self.airport.totalBoarding/self.airport.cur_passenger)
        
        if self.airport.cur_passenger == self.airport.num_passengers:
            print("Average Checkin Time: ", self.airport.totalCheckin/self.airport.num_passengers)
            print("Average Security Time: ", self.airport.totalSecurity/self.airport.num_passengers)
            print("Average Boarding Time: ", self.airport.totalBoarding/self.airport.num_passengers)
            custList = list(range(1,101))
            
            # Plotting average Checking
            plt.figure()
            plt.title("Average Checking Time vs No of Customers")
            plt.scatter(custList, self.airport.avgCheckin)
            plt.plot(custList, self.airport.avgCheckin)
            plt.savefig('checking_time_vs_customers.png')
            
            #Average Security
            plt.figure()
            plt.title("Average Security Time vs No of Customers")
            plt.scatter(custList, self.airport.avgSecurity)
            plt.plot(custList, self.airport.avgSecurity)
            plt.savefig('security_time_vs_customers.png')
            
            # Average Boarding
            plt.figure()
            plt.title("Average Boarding Time vs No of Customers")
            plt.scatter(custList, self.airport.avgBoarding)
            plt.plot(custList, self.airport.avgBoarding)
            plt.savefig('boarding_time_vs_customers.png')

            plt.show()
            
class Gui(QMainWindow):
    def __init__(self):
        super().__init__()
        self.myfont = QFont()
        self.myfont.setPointSize(15)
        self.setWindowTitle("Airport Simulation")
        self.setMinimumSize(QSize(960, 720))
        self.airport = Airport()
        self.checkin_labels = [
            QLabel(f"[C{i+1}]", self) for i in range(self.airport.num_checkin)
        ]
        self.security_labels = [
            QLabel(f"[S{i+1}]", self) for i in range(self.airport.num_security)
        ]
        self.boarding_labels = [
            QLabel(f"[B{i+1}]", self) for i in range(self.airport.num_boarding)
        ]
        c_x = 100
        c_y = 150
        s_x = 400
        s_y = 150
        b_x = 700
        b_y = 150
        for i in range(self.airport.num_checkin):
            self.checkin_labels[i].move(c_x + i*50, c_y)
            self.checkin_labels[i].adjustSize()
        for i in range(self.airport.num_security):
            self.security_labels[i].move(s_x + i*50, s_y)
            self.security_labels[i].adjustSize()
        for i in range(self.airport.num_boarding):
            self.boarding_labels[i].move(b_x + i*50, b_y)
            self.boarding_labels[i].adjustSize()

        self.time_label = QLabel(f"time: {self.airport.env.now}", self)
        self.time_label.move(400, 25)
        self.checkin_num_label = QLabel(f"{self.airport.curr_checkin}", self)
        self.checkin_num_label.move(100, 200)
        self.security_num_label = QLabel(f"{self.airport.curr_security}", self)
        self.security_num_label.move(400, 200)
        self.boarding_num_label = QLabel(f"{self.airport.curr_boarding}", self)
        self.boarding_num_label.move(700, 200)
        self.done_num_label = QLabel(f"done: {self.airport.curr_done}", self)
        self.done_num_label.move(400, 300)

        self.next_button = QPushButton("Next Time Step", self)
        self.next_button.move(400, 400)
        self.next_button.resize(100, 50)
        self.next_button.setFont(self.myfont)
        self.next_button.adjustSize()
        self.next_button.clicked.connect(self.nextStep)
        self.ff_button = QPushButton("Fast Forward to the end", self)
        self.ff_button.move(400, 500)
        self.ff_button.resize(100, 50)
        self.ff_button.setFont(self.myfont)
        self.ff_button.adjustSize()
        self.ff_button.clicked.connect(self.fastForward)

    def updateUI(self):
        self.time_label.setText(f"time:{self.airport.env.now}")
        self.time_label.adjustSize()
        self.checkin_num_label.setText(f"{self.airport.curr_checkin}")
        self.checkin_num_label.adjustSize()
        self.security_num_label.setText(f"{self.airport.curr_security}")
        self.security_num_label.adjustSize()
        self.boarding_num_label.setText(f"{self.airport.curr_boarding}")
        self.boarding_num_label.adjustSize()
        self.done_num_label.setText(f"done: {self.airport.curr_done}")
        self.done_num_label.adjustSize()

    def nextStep(self):
        try:
            self.airport.env.step()
        except simpy.core.EmptySchedule:
            print("finished")
            return False
        curr_time = self.airport.env.now
        while self.airport.env.peek() == curr_time:
            try:
                self.airport.env.step()
            except simpy.core.EmptySchedule:
                print("finished")
                return False

        self.updateUI()
        
        return True

    def fastForward(self):
        self.airport.env.run()
        self.updateUI()
        
                

app = QApplication(sys.argv)
myfont = QFont()
myfont.setWeight(60)
myfont.setPointSize(20)
app.setFont(myfont, 'QLabel')
gui = Gui()
gui.show()
sys.exit(app.exec_())


# airport.env.run()
# Out:
# time: 0 passenger arrived
# time: 2 checking in done
# time: 3 passenger arrived
# time: 3 passenger arrived
# time: 4 passenger arrived
# time: 6 passenger arrived
# time: 7 passenger arrived
# time: 7 checking in done
# time: 8 security check done
# time: 8 checking in done
# time: 9 checking in done
# time: 9 checking in done
# time: 9 checking in done
# time: 9 security check done
# time: 10 passenger arrived
# time: 10 boarding done
# time: 10 passenger arrived at 0 and done at 10
# time: 11 passenger arrived
# time: 11 passenger arrived
# time: 12 security check done
# time: 12 boarding done
# time: 12 passenger arrived at 3 and done at 12
# time: 13 passenger arrived
# time: 13 passenger arrived
# time: 13 security check done
# time: 13 security check done
# time: 13 checking in done
# time: 14 passenger arrived
# time: 14 security check done
# time: 14 checking in done
# time: 14 boarding done
# time: 14 passenger arrived at 3 and done at 14
# time: 15 checking in done
# time: 15 checking in done
# time: 15 boarding done
# time: 15 passenger arrived at 4 and done at 15
# time: 16 checking in done
# time: 16 security check done
# time: 16 security check done
# time: 16 boarding done
# time: 16 passenger arrived at 7 and done at 16
# time: 17 checking in done
# time: 18 passenger arrived
# time: 18 passenger arrived
# time: 18 security check done
# time: 18 boarding done
# time: 18 passenger arrived at 6 and done at 18
# time: 19 passenger arrived
# time: 19 security check done
# time: 19 checking in done
# time: 19 boarding done
# time: 19 passenger arrived at 11 and done at 19
# time: 20 passenger arrived
# time: 20 security check done
# time: 21 passenger arrived
# time: 21 checking in done
# time: 21 boarding done
# time: 21 passenger arrived at 10 and done at 21
# time: 21 checking in done
# time: 23 security check done
# time: 23 checking in done
# time: 23 boarding done
# time: 23 passenger arrived at 14 and done at 23
# time: 24 checking in done
# time: 24 security check done
# time: 24 boarding done
# time: 24 passenger arrived at 13 and done at 24
# time: 25 passenger arrived
# time: 25 security check done
# time: 25 security check done
# time: 25 security check done
# time: 25 boarding done
# time: 25 passenger arrived at 11 and done at 25
# time: 26 passenger arrived
# time: 26 boarding done
# time: 26 passenger arrived at 13 and done at 26
# time: 28 boarding done
# time: 28 passenger arrived at 20 and done at 28
# time: 29 passenger arrived
# time: 29 security check done
# time: 29 checking in done
# time: 29 checking in done
# time: 30 passenger arrived
# time: 30 passenger arrived
# time: 30 passenger arrived
# time: 30 boarding done
# time: 30 passenger arrived at 18 and done at 30
# time: 31 checking in done
# time: 31 boarding done
# time: 31 passenger arrived at 19 and done at 31
# time: 33 passenger arrived
# time: 33 passenger arrived
# time: 33 passenger arrived
# time: 33 passenger arrived
# time: 33 passenger arrived
# time: 33 checking in done
# time: 33 security check done
# time: 33 security check done
# time: 33 boarding done
# time: 33 passenger arrived at 18 and done at 33
# time: 34 security check done
# time: 34 checking in done
# time: 34 checking in done
# time: 34 checking in done
# time: 34 boarding done
# time: 34 passenger arrived at 21 and done at 34
# time: 35 boarding done
# time: 35 passenger arrived at 25 and done at 35
# time: 36 passenger arrived
# time: 36 passenger arrived
# time: 36 passenger arrived
# time: 36 passenger arrived
# time: 36 checking in done
# time: 37 passenger arrived
# time: 37 security check done
# time: 37 checking in done
# time: 37 boarding done
# time: 37 passenger arrived at 30 and done at 37
# time: 37 checking in done
# time: 38 passenger arrived
# time: 38 checking in done
# time: 38 checking in done
# time: 38 security check done
# time: 38 boarding done
# time: 38 passenger arrived at 26 and done at 38
# time: 39 passenger arrived
# time: 39 passenger arrived
# time: 39 security check done
# time: 39 checking in done
# time: 39 security check done
# time: 39 checking in done
# time: 39 checking in done
# time: 39 boarding done
# time: 39 passenger arrived at 29 and done at 39
# time: 40 passenger arrived
# time: 40 security check done
# time: 40 security check done
# time: 40 checking in done
# time: 40 boarding done
# time: 40 passenger arrived at 30 and done at 40
# time: 41 passenger arrived
# time: 41 passenger arrived
# time: 41 security check done
# time: 41 checking in done
# time: 42 passenger arrived
# time: 42 checking in done
# time: 42 checking in done
# time: 42 security check done
# time: 42 boarding done
# time: 42 passenger arrived at 33 and done at 42
# time: 43 passenger arrived
# time: 43 passenger arrived
# time: 43 passenger arrived
# time: 43 security check done
# time: 43 security check done
# time: 43 security check done
# time: 43 security check done
# time: 44 passenger arrived
# time: 44 passenger arrived
# time: 44 passenger arrived
# time: 44 checking in done
# time: 44 checking in done
# time: 44 boarding done
# time: 44 passenger arrived at 33 and done at 44
# time: 45 checking in done
# time: 45 checking in done
# time: 45 boarding done
# time: 45 passenger arrived at 30 and done at 45
# time: 46 security check done
# time: 46 security check done
# time: 46 security check done
# time: 46 checking in done
# time: 46 checking in done
# time: 46 boarding done
# time: 46 passenger arrived at 36 and done at 46
# time: 47 checking in done
# time: 47 security check done
# time: 47 checking in done
# time: 47 checking in done
# time: 47 boarding done
# time: 47 passenger arrived at 33 and done at 47
# time: 48 boarding done
# time: 48 passenger arrived at 33 and done at 48
# time: 49 security check done
# time: 49 checking in done
# time: 49 security check done
# time: 49 boarding done
# time: 49 passenger arrived at 33 and done at 49
# time: 50 security check done
# time: 51 passenger arrived
# time: 51 security check done
# time: 51 security check done
# time: 51 boarding done
# time: 51 passenger arrived at 36 and done at 51
# time: 52 boarding done
# time: 52 passenger arrived at 37 and done at 52
# time: 53 passenger arrived
# time: 53 passenger arrived
# time: 53 passenger arrived
# time: 53 security check done
# time: 53 security check done
# time: 53 checking in done
# time: 53 security check done
# time: 54 security check done
# time: 54 boarding done
# time: 54 passenger arrived at 38 and done at 54
# time: 55 passenger arrived
# time: 55 passenger arrived
# time: 56 security check done
# time: 56 checking in done
# time: 56 boarding done
# time: 56 passenger arrived at 39 and done at 56
# time: 56 checking in done
# time: 57 passenger arrived
# time: 57 passenger arrived
# time: 57 checking in done
# time: 57 checking in done
# time: 57 boarding done
# time: 57 passenger arrived at 40 and done at 57
# time: 58 passenger arrived
# time: 58 security check done
# time: 58 checking in done
# time: 59 passenger arrived
# time: 59 security check done
# time: 59 checking in done
# time: 59 security check done
# time: 59 security check done
# time: 59 boarding done
# time: 59 passenger arrived at 39 and done at 59
# time: 59 checking in done
# time: 60 passenger arrived
# time: 60 security check done
# time: 61 passenger arrived
# time: 61 passenger arrived
# time: 61 security check done
# time: 61 security check done
# time: 61 boarding done
# time: 61 passenger arrived at 36 and done at 61
# time: 62 checking in done
# time: 63 passenger arrived
# time: 63 passenger arrived
# time: 63 checking in done
# time: 63 checking in done
# time: 63 checking in done
# time: 63 boarding done
# time: 63 passenger arrived at 36 and done at 63
# time: 64 security check done
# time: 64 checking in done
# time: 64 boarding done
# time: 64 passenger arrived at 41 and done at 64
# time: 66 passenger arrived
# time: 66 security check done
# time: 66 security check done
# time: 66 checking in done
# time: 66 boarding done
# time: 66 passenger arrived at 41 and done at 66
# time: 67 passenger arrived
# time: 67 passenger arrived
# time: 67 security check done
# time: 68 passenger arrived
# time: 68 security check done
# time: 68 checking in done
# time: 68 boarding done
# time: 68 passenger arrived at 42 and done at 68
# time: 68 checking in done
# time: 68 checking in done
# time: 69 security check done
# time: 69 boarding done
# time: 69 passenger arrived at 43 and done at 69
# time: 70 passenger arrived
# time: 70 security check done
# time: 70 checking in done
# time: 70 checking in done
# time: 70 security check done
# time: 70 security check done
# time: 70 boarding done
# time: 70 passenger arrived at 44 and done at 70
# time: 71 boarding done
# time: 71 passenger arrived at 44 and done at 71
# time: 72 passenger arrived
# time: 72 security check done
# time: 72 boarding done
# time: 72 passenger arrived at 44 and done at 72
# time: 73 passenger arrived
# time: 74 passenger arrived
# time: 74 passenger arrived
# time: 74 checking in done
# time: 74 boarding done
# time: 74 passenger arrived at 43 and done at 74
# time: 74 checking in done
# time: 75 passenger arrived
# time: 75 passenger arrived
# time: 75 checking in done
# time: 75 security check done
# time: 75 security check done
# time: 76 passenger arrived
# time: 76 checking in done
# time: 76 boarding done
# time: 76 passenger arrived at 43 and done at 76
# time: 76 checking in done
# time: 77 passenger arrived
# time: 77 passenger arrived
# time: 77 passenger arrived
# time: 77 passenger arrived
# time: 77 checking in done
# time: 77 security check done
# time: 78 passenger arrived
# time: 78 passenger arrived
# time: 78 security check done
# time: 78 checking in done
# time: 78 boarding done
# time: 78 passenger arrived at 55 and done at 78
# time: 79 checking in done
# time: 79 checking in done
# time: 79 boarding done
# time: 79 passenger arrived at 51 and done at 79
# time: 80 checking in done
# time: 80 security check done
# time: 80 checking in done
# time: 81 security check done
# time: 81 boarding done
# time: 81 passenger arrived at 53 and done at 81
# time: 82 security check done
# time: 82 security check done
# time: 82 checking in done
# time: 83 checking in done
# time: 83 boarding done
# time: 83 passenger arrived at 53 and done at 83
# time: 84 passenger arrived
# time: 84 security check done
# time: 84 checking in done
# time: 85 security check done
# time: 85 boarding done
# time: 85 passenger arrived at 53 and done at 85
# time: 86 passenger arrived
# time: 86 passenger arrived
# time: 86 security check done
# time: 87 passenger arrived
# time: 87 security check done
# time: 87 checking in done
# time: 87 boarding done
# time: 87 passenger arrived at 57 and done at 87
# time: 87 checking in done
# time: 88 security check done
# time: 88 security check done
# time: 88 boarding done
# time: 88 passenger arrived at 55 and done at 88
# time: 89 passenger arrived
# time: 89 passenger arrived
# time: 89 security check done
# time: 90 boarding done
# time: 90 passenger arrived at 58 and done at 90
# time: 91 passenger arrived
# time: 91 passenger arrived
# time: 91 checking in done
# time: 91 boarding done
# time: 91 passenger arrived at 61 and done at 91
# time: 92 passenger arrived
# time: 92 passenger arrived
# time: 92 security check done
# time: 92 checking in done
# time: 92 security check done
# time: 92 boarding done
# time: 92 passenger arrived at 61 and done at 92
# time: 93 passenger arrived
# time: 93 passenger arrived
# time: 93 checking in done
# time: 93 checking in done
# time: 93 checking in done
# time: 93 checking in done
# time: 94 passenger arrived
# time: 94 passenger arrived
# time: 94 passenger arrived
# time: 94 security check done
# time: 94 boarding done
# time: 94 passenger arrived at 59 and done at 94
# time: 95 passenger arrived
# time: 95 checking in done
# time: 95 security check done
# time: 95 checking in done
# time: 96 passenger arrived
# time: 96 passenger arrived
# time: 96 boarding done
# time: 96 passenger arrived at 57 and done at 96
# time: 97 security check done
# time: 97 security check done
# time: 97 checking in done
# time: 98 passenger arrived
# time: 98 security check done
# time: 98 checking in done
# time: 98 checking in done
# time: 98 security check done
# time: 98 boarding done
# time: 98 passenger arrived at 63 and done at 98
# time: 99 passenger arrived
# time: 99 passenger arrived
# time: 99 checking in done
# time: 99 security check done
# time: 100 security check done
# time: 100 checking in done
# time: 100 security check done
# time: 100 checking in done
# time: 100 boarding done
# time: 100 passenger arrived at 60 and done at 100
# time: 100 checking in done
# time: 101 security check done
# time: 101 security check done
# time: 101 checking in done
# time: 101 security check done
# time: 102 checking in done
# time: 102 security check done
# time: 102 boarding done
# time: 102 passenger arrived at 67 and done at 102
# time: 103 checking in done
# time: 103 security check done
# time: 104 checking in done
# time: 104 boarding done
# time: 104 passenger arrived at 67 and done at 104
# time: 105 security check done
# time: 105 security check done
# time: 105 security check done
# time: 105 boarding done
# time: 105 passenger arrived at 63 and done at 105
# time: 106 security check done
# time: 106 boarding done
# time: 106 passenger arrived at 66 and done at 106
# time: 108 security check done
# time: 108 boarding done
# time: 108 passenger arrived at 68 and done at 108
# time: 109 boarding done
# time: 109 passenger arrived at 73 and done at 109
# time: 110 security check done
# time: 111 boarding done
# time: 111 passenger arrived at 72 and done at 111
# time: 113 boarding done
# time: 113 passenger arrived at 74 and done at 113
# time: 114 boarding done
# time: 114 passenger arrived at 70 and done at 114
# time: 116 boarding done
# time: 116 passenger arrived at 74 and done at 116
# time: 117 boarding done
# time: 117 passenger arrived at 75 and done at 117
# time: 119 boarding done
# time: 119 passenger arrived at 76 and done at 119
# time: 121 boarding done
# time: 121 passenger arrived at 77 and done at 121
# time: 122 boarding done
# time: 122 passenger arrived at 77 and done at 122
# time: 124 boarding done
# time: 124 passenger arrived at 77 and done at 124
# time: 125 boarding done
# time: 125 passenger arrived at 75 and done at 125
# time: 127 boarding done
# time: 127 passenger arrived at 78 and done at 127
# time: 129 boarding done
# time: 129 passenger arrived at 77 and done at 129
# time: 130 boarding done
# time: 130 passenger arrived at 78 and done at 130
# time: 131 boarding done
# time: 131 passenger arrived at 84 and done at 131
# time: 133 boarding done
# time: 133 passenger arrived at 86 and done at 133
# time: 134 boarding done
# time: 134 passenger arrived at 89 and done at 134
# time: 135 boarding done
# time: 135 passenger arrived at 86 and done at 135
# time: 136 boarding done
# time: 136 passenger arrived at 89 and done at 136
# time: 138 boarding done
# time: 138 passenger arrived at 87 and done at 138
# time: 140 boarding done
# time: 140 passenger arrived at 91 and done at 140
# time: 142 boarding done
# time: 142 passenger arrived at 93 and done at 142
# time: 143 boarding done
# time: 143 passenger arrived at 92 and done at 143
# time: 145 boarding done
# time: 145 passenger arrived at 91 and done at 145
# time: 147 boarding done
# time: 147 passenger arrived at 94 and done at 147
# time: 148 boarding done
# time: 148 passenger arrived at 92 and done at 148
# time: 150 boarding done
# time: 150 passenger arrived at 93 and done at 150
# time: 151 boarding done
# time: 151 passenger arrived at 94 and done at 151
# time: 153 boarding done
# time: 153 passenger arrived at 95 and done at 153
# time: 155 boarding done
# time: 155 passenger arrived at 94 and done at 155
# time: 157 boarding done
# time: 157 passenger arrived at 96 and done at 157
# time: 159 boarding done
# time: 159 passenger arrived at 96 and done at 159
# time: 161 boarding done
# time: 161 passenger arrived at 98 and done at 161
# time: 163 boarding done
# time: 163 passenger arrived at 99 and done at 163
# time: 165 boarding done
# time: 165 passenger arrived at 99 and done at 165
# Average Checkin Time:  3.26
# Average Security Time:  7.8
# Average Boarding Time:  31.36
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\ASUS\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3333: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
